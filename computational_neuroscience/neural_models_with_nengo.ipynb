# %%
import nengo
from nengo.dists import Uniform
import numpy as np
import matplotlib.pyplot as plt
from nengo.utils.matplotlib import rasterplot
from nengo.utils.ensemble import tuning_curves
from nengo.dists import Choice

# %%
rng = np.random.default_rng()
theta = np.rad2deg(rng.vonmises(np.deg2rad(225), 1, 1000))

def plot_angle_distribution(ax: plt.Axes, thetas: np.ndarray, density: bool = True):
    ax.hist(thetas, bins = 90, density=density, alpha = 0.75)
    ax.set_xlabel('Theta')
    ax.set_ylabel('Probability' if density else 'Frequency')

fig, ax = plt.subplots(1, 1)
plot_angle_distribution(ax, theta)
plt.show()

# %% [markdown]
# ## Generate an input signal from the movement of dots

# %%
def generate_dot_directions(
    motion_direction_deg: float,
    vonmises_concentration: float,
    num_dots: int,
    coherence: float,
):
    coherent_direction = np.rad2deg(rng.vonmises(np.deg2rad(motion_direction_deg), vonmises_concentration))
    directions = rng.integers(-180, 180, size = num_dots)
    # select a % of the dots
    coherent_dots_index = rng.choice(np.arange(0, len(directions)), size = int(coherence * len(directions)), replace = False)
    directions[coherent_dots_index] = coherent_direction
    return directions
    
thetas = generate_dot_directions(225, 2.0, 300, 0.05)
fig, ax = plt.subplots(1, 1)
plot_angle_distribution(ax, thetas, density = False)
plt.show()

# %% [markdown]
# # Create a single neuron population that receives a Sine wave as input

# %%
model = nengo.Network()
with model:
    input = nengo.Node(lambda x: np.sin(10*x))
    ensemble = nengo.Ensemble(
        1,
        dimensions = 1, # State space has a single dimension (i.e a scalar)
        intercepts = Uniform(-0.5, 0.5), # Represents the 0 values of the dimension
        max_rates = Uniform(100, 100), # Neuron only fires at 100Hz max
        encoders = [[1]], # N x M where N = # of neurons, M = # of dimensions of input space. This represents how inputs are converted into Neuron representational space.
    )

    nengo.Connection(input, ensemble)
    
    # Set up probes
    input_probe = nengo.Probe(input)
    # The raw spikes from the neuron
    spikes = nengo.Probe(ensemble.neurons)
    # Subthreshold soma voltage of the neuron
    voltage = nengo.Probe(ensemble.neurons, "voltage")
    # Spikes filtered by a 10ms post-synaptic filter
    filtered = nengo.Probe(ensemble, synapse=0.01)
    
with nengo.Simulator(model) as sim:
    sim.run(1) # 1 second
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('373258fe-de65-465a-90b9-a181762d2910');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('5251eb73-8eb9-4021-b95a-15007258721c');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:01.';
#
#             if (100.0 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '100.0%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>

# %%
# Plot the decoded output of the ensemble
plt.figure()
plt.plot(sim.trange(), sim.data[filtered], label = "Decoded Population Value")
plt.plot(sim.trange(), sim.data[input_probe], label = "Input Value")
plt.xlabel("Time (ms)")
plt.legend(loc = "upper right")
plt.xlim(0, 1)

# Plot the spiking output of the ensemble
plt.figure(figsize=(10, 8))
plt.subplot(221)
plt.title("Population Spike Time Raster")
rasterplot(sim.trange(), sim.data[spikes])
plt.ylabel("Neuron")
plt.xlim(0, 1)

# Plot the soma voltages of the neurons
plt.subplot(222)
plt.title("Population Spikes")
plt.plot(sim.trange(), sim.data[voltage][:, 0], "r")
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
plt.figure()
plt.plot(*tuning_curves(ensemble, sim))
plt.ylabel("Firing Rate (Hz)")
plt.xlabel("Input Scalar")
plt.show()

# %% [markdown]
# # Create a population with many neurons receiving a scalar input

# %%
model = nengo.Network()
with model:
    input = nengo.Node(lambda x: np.sin(10*x))
    ensemble = nengo.Ensemble(
        10,
        dimensions = 1,
        max_rates = Uniform(100, 200),
        intercepts = Uniform(-0.5, 0.5),
    )

    nengo.Connection(input, ensemble)

    # Set up probes
    input_probe = nengo.Probe(input)
    # The raw spikes from the neuron
    spikes = nengo.Probe(ensemble.neurons)
    # Subthreshold soma voltage of the neuron
    voltage = nengo.Probe(ensemble.neurons, "voltage")
    # Spikes filtered by a 10ms post-synaptic filter
    filtered = nengo.Probe(ensemble, synapse=0.01)

with nengo.Simulator(model) as sim:
    sim.run(1) # 1 second
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('2a4414c8-2c10-4854-bc38-bb3277bbde97');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('325c8dd6-5edb-42ef-9668-bc20529b8b87');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:01.';
#
#             if (100.0 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '100.0%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>

# %%
# Plot the decoded output of the ensemble
plt.figure()
plt.plot(sim.trange(), sim.data[filtered], label = "Decoded Population Value")
plt.plot(sim.trange(), sim.data[input_probe], label = "Input Value")
plt.xlabel("Time (ms)")
plt.legend(loc = "upper right")
plt.xlim(0, 1)

# Plot the spiking output of the ensemble
plt.figure(figsize=(10, 8))
plt.subplot(221)
plt.title("Population Spike Time Raster")
rasterplot(sim.trange(), sim.data[spikes])
plt.ylabel("Neuron")
plt.xlim(0, 1)

# Plot the soma voltages of the neurons
plt.subplot(222)
plt.title("Population Spikes")
plt.plot(sim.trange(), sim.data[voltage][:, 0], "r")
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Plot tuning curves for scalar representation

# %%
plt.figure()
plt.plot(*tuning_curves(ensemble, sim))
plt.ylabel("Firing Rate (Hz)")
plt.xlabel("Input Scalar")
plt.show()

# %%
ensemble.encoders = Choice([[1]])

with nengo.Simulator(model) as sim:
    plt.plot(*tuning_curves(ensemble, sim))
plt.plot(*tuning_curves(ensemble, sim))
plt.ylabel("Firing rate (Hz)")
plt.xlabel("Input scalar, x")
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('3fe781f0-eab7-4bdd-aae2-f887df6660f8');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# Text(0.5, 0, 'Input scalar, x')

# %% [markdown]
# # Explorations in Learning
#
# What happens when you pass the scalar signal across two populations of Neurons?

# %%
model = nengo.Network()
with model:
    input = nengo.Node(lambda x: np.sin(10*x))
    pre = nengo.Ensemble(
        10,
        dimensions = 1,
        max_rates = Uniform(100, 200),
        intercepts = Uniform(-0.5, 0.5),
    )
    post = nengo.Ensemble(5, dimensions = 1)
    error = nengo.Ensemble(20, dimensions = 1)
    error_p = nengo.Probe(error, synapse=0.03)


    nengo.Connection(input, pre)
    pre_post_conn = nengo.Connection(pre, post, function = lambda x: rng.random())

    # Error = actual - target = post - pre
    nengo.Connection(post, error)
    nengo.Connection(pre, error, transform=-1)

    pre_post_conn.learning_rule_type = nengo.PES()
    nengo.Connection(error, pre_post_conn.learning_rule)
    
    # Set up probes
    input_probe = nengo.Probe(input)
    # The raw spikes from the neuron
    pre_spikes = nengo.Probe(pre.neurons)
    # Spikes filtered by a 10ms post-synaptic filter
    pre_decoded = nengo.Probe(pre, synapse=0.01)

    post_spikes = nengo.Probe(post.neurons)
    # Spikes filtered by a 10ms post-synaptic filter
    post_decoded = nengo.Probe(post, synapse=0.01)

with nengo.Simulator(model) as sim:
    sim.run(5.0) # 1 second
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('881d2296-199f-490c-858b-3f7a37e7e55c');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:01.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('314db5be-02e5-4b88-9e7a-2e02f27d94ac');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:01.';
#
#             if (100.0 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '100.0%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 1, 1)
plt.plot(sim.trange(), sim.data[input_probe].T[0], c="k", label="Input")
plt.plot(sim.trange(), sim.data[pre_decoded].T[0], c="b", label="Pre")
plt.plot(sim.trange(), sim.data[post_decoded].T[0], c="r", label="Post")
plt.ylabel("Dimension 1")
plt.legend(loc="best")

# %% [markdown]
# # Learning vectors on a unit circle (i.e motion directions)

# %% [markdown]
# ## Let's first generate some angles, and plot their unit vectors

# %%
def create_unit_vectors_from_thetas(thetas: np.ndarray) -> np.ndarray:
    radians = np.deg2rad(thetas)
    x = np.cos(radians)
    y = np.sin(radians)
    vectors = np.column_stack((x, y))
    return vectors

def plot_unit_vectors(vectors: np.ndarray, alpha: float = 0.1) -> None:
     # Create a unit circle
    circle = plt.Circle((0, 0), 1, color='blue', fill=False, linestyle='--')

    fig, ax = plt.subplots()
    ax.add_artist(circle)

    # Plot each vector
    for vector in vectors:
        ax.plot([0, vector[0]], [0, vector[1]], 'r-', alpha=alpha)

    # Set the aspect ratio of the plot to be equal
    ax.set_aspect('equal')

    # Set limits to make sure the circle is visible
    ax.set_xlim([-1.5, 1.5])
    ax.set_ylim([-1.5, 1.5])

     # Plot axis lines
    ax.plot([-1.5, 1.5], [0, 0], 'k--', alpha=0.7)  # X-axis
    ax.plot([0, 0], [-1.5, 1.5], 'k--', alpha=0.7)  # Y-axis

    # Add grid
    ax.grid(True)

    # Display the plot
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('Unit Vectors on a Unit Circle')
    plt.show()

thetas = generate_dot_directions(225, 4.0, 700, 0.30)
vectors = create_unit_vectors_from_thetas(thetas)

# %%
fig, ax = plt.subplots(1, 1)
plot_angle_distribution(ax, thetas, density = False)
plot_unit_vectors(vectors)
plt.show()

# %% [markdown]
# ## Now let's implement a circuit that can learn this vector

# %%
class VectorInput:
    def __init__(self, vectors: np.ndarray):
        self.vectors = vectors
        self.current = 0
    
    def step(self):
        current_vector = self.vectors[self.current % len(vectors), :]
        self.current += 1
        return current_vector

def vector_to_angle(x):
    return np.rad2deg(np.arctan2(x[1], x[0]))

model = nengo.Network()
with model:
    vector_inputs = VectorInput(vectors)
    input = nengo.Node(lambda t, x: vector_inputs.step(), size_in = 2, size_out=2) # Pass in 2D vectors
    input_ensemble = nengo.Ensemble(
        500,
        dimensions = 2,
        radius=1,
    )
    angle_ensemble = nengo.Ensemble(
        500,
        dimensions = 1,
        radius = 180, 
    )
    nengo.Connection(input_ensemble, angle_ensemble, function=vector_to_angle)

    learned_ensemble = nengo.Ensemble(
        500,
        dimensions = 1,
        radius=180,
    )
    nengo.Connection(input, input_ensemble)
    learning_connection = nengo.Connection(
        angle_ensemble,
        learned_ensemble,
        function = lambda x: x,
        learning_rule_type= nengo.PES(learning_rate=1e-4),
    )
    error_ensemble = nengo.Ensemble(20, dimensions = 1)
    
    nengo.Connection(error_ensemble, learning_connection.learning_rule)
    nengo.Connection(learned_ensemble, error_ensemble, transform=-1)
    nengo.Connection(angle_ensemble, error_ensemble, transform=1)
    
    input_signal_probe = nengo.Probe(input)
    error_ensemble_probe = nengo.Probe(error_ensemble, synapse=0.01)
    input_ensemble_probe = nengo.Probe(input_ensemble, synapse=0.01)
    angle_ensemble_probe = nengo.Probe(angle_ensemble, synapse=0.01)
    learned_ensemble_probe = nengo.Probe(learned_ensemble, synapse=0.01)

with nengo.Simulator(model) as sim:
    sim.run(10) # 1 second
# Out:
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('cc523789-069c-404e-8068-efdd9aa7cc1d');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Build finished in 0:00:02.';
#
#             fill.style.width = '100%';
#             fill.style.animation = 'pb-fill-anim 2s linear infinite';
#             fill.style.backgroundSize = '100px 100%';
#             fill.style.backgroundImage = 'repeating-linear-gradient(' +
#                 '90deg, #bdd2e6, #edf2f8 40%, #bdd2e6 80%, #bdd2e6)';
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc['progress']['progress_bar'] = 'nengo.utils.progress.TerminalProgressBar'`.
# <script>
#               (function () {
#                   var root = document.getElementById('6212794d-cfda-4199-870f-555133d98ef1');
#                   var text = root.getElementsByClassName('pb-text')[0];
#                   var fill = root.getElementsByClassName('pb-fill')[0];
#
#                   text.innerHTML = 'Simulation finished in 0:00:02.';
#
#             if (100.0 > 0.) {
#                 fill.style.transition = 'width 0.1s linear';
#             } else {
#                 fill.style.transition = 'none';
#             }
#
#             fill.style.width = '100.0%';
#             fill.style.animation = 'none';
#             fill.style.backgroundImage = 'none'
#
#
#                 fill.style.animation = 'none';
#                 fill.style.backgroundImage = 'none';
#
#               })();
#         </script>

# %%
plt.figure(figsize=(12, 16))

plt.subplot(411)
plt.hist(sim.data[input_signal_probe])
# plt.plot(sim.trange(), sim.data[input_signal_probe])
plt.title("Input Vectors")
plt.ylabel("Value")
plt.legend(["X", "Y"])

plt.subplot(412)
plt.plot(sim.trange(), sim.data[input_ensemble_probe])
plt.title("Input Ensemble Representation")
plt.ylabel("Value")
plt.legend(["X", "Y"])

plt.subplot(412)
plt.hist(sim.data[angle_ensemble_probe], bins = 35)
# plt.plot(sim.trange(), sim.data[angle_ensemble_probe])
plt.title("Angle Ensemble Representation")
plt.ylabel("Value")
plt.legend(["Time", "Theta"])

plt.subplot(413)
plt.plot(sim.trange(), sim.data[learned_ensemble_probe])
plt.title("Output Ensemble (Learned) Representation")
plt.ylabel("Value")
plt.legend(["X", "Y"])

plt.subplot(414)
plt.plot(sim.trange(), sim.data[error_ensemble_probe])
plt.title("Error Signal")
plt.xlabel("Time (s)")
plt.ylabel("Error")
plt.legend(["X", "Y"])

plt.tight_layout()
plt.show()

# Plot input vs output after learning
plt.figure(figsize=(8, 8))
plt.scatter(sim.data[input_signal_probe][-1000:, 0], sim.data[input_signal_probe][-1000:, 1],
            alpha=0.5, label='Input')
plt.scatter(sim.data[learned_ensemble_probe][-1000:, 0], sim.data[learned_ensemble_probe][-1000:, 1],
            alpha=0.5, label='Output')
plt.title("Input vs Learned Output (Last 1000 samples)")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 43
#      40 plt.figure(figsize=(8, 8))
#      41 plt.scatter(sim.data[input_signal_probe][-1000:, 0], sim.data[input_signal_probe][-1000:, 1],
#      42             alpha=0.5, label='Input')
# ---> 43 plt.scatter(sim.data[learned_ensemble_probe][-1000:, 0], sim.data[learned_ensemble_probe][-1000:, 1],
#      44             alpha=0.5, label='Output')
#      45 plt.title("Input vs Learned Output (Last 1000 samples)")
#      46 plt.xlabel("X")
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %% [markdown]
# ## WIP - learning the prior and combinging the sensory evidence

# %%
import nengo
import numpy as np
from nengo.dists import Uniform
from nengo.processes import WhiteSignal

# Define parameters
n_neurons = 100
learning_rate = 1e-4
simulation_time = 10  # seconds

# Create the model
model = nengo.Network()
with model:
    # Input: simulated motion direction (in radians)
    motion_input = nengo.Node(WhiteSignal(period=2, high=0.5, rms=0.5))
    
    # Sensory evidence ensemble
    sensory = nengo.Ensemble(n_neurons, dimensions=1, 
                             radius=np.pi)  # represents angles
    
    # Prior ensemble (will learn over time)
    prior = nengo.Ensemble(n_neurons, dimensions=1, 
                           radius=np.pi)
    
    # Decision ensemble (combines sensory and prior)
    decision = nengo.Ensemble(n_neurons, dimensions=1, 
                              radius=np.pi)
    
    # Connect input to sensory ensemble
    nengo.Connection(motion_input, sensory)
    
    # Learn the prior
    conn_learn = nengo.Connection(
        sensory, prior,
        function=lambda x: 0,  # Start with a flat prior
        learning_rule_type=nengo.PES(learning_rate)
    )
    nengo.Connection(sensory, conn_learn.learning_rule)
    
    # Implement switching
    def switch(x):
        sensory, prior = x
        # Simple switching rule: choose sensory if strong, otherwise prior
        return sensory if abs(sensory) > 0.5 else prior
    
    nengo.Connection(sensory, decision[0])
    nengo.Connection(prior, decision[1])
    nengo.Connection(decision, decision, function=switch)
    
    # Probes for plotting
    p_sensory = nengo.Probe(sensory, synapse=0.01)
    p_prior = nengo.Probe(prior, synapse=0.01)
    p_decision = nengo.Probe(decision, synapse=0.01)

# Run the simulation
with nengo.Simulator(model) as sim:
    sim.run(simulation_time)

# Plotting code (not shown) would go here to visualize results
